# %% [markdown]
# # Лабораторная работа №2
# ## Выполнил студент группы Левин А.С БФИ2001

# %% [markdown]
# ### Оглавление
# 1. [Задание 1](#Задание-№1)
# 2. [Задание 2](#Задание-№2)
# 3. [Задание 3](#Задание-№3)

# %% [markdown]
# ### Задание №1
# Реализовать методы поиска в соответствии с заданием. Организовать генерацию начального набора случайных данных. Для всех вариантов добавить реализацию добавления, поиска и удаления элементов. Оценить время работы каждого алгоритма поиска и сравнить его со временем работы стандартной функции поиска, используемой в выбранном языке программирования.

# %%
import random
def generator(mas_len,min_d,max_d):
    return [random.randint(min_d,max_d+1) for i in range(mas_len)]

# %%
#Бинарный поиск
def bin_search(mas,n):
    first = 0
    last = len(mas)-1
    index = -1
    while (first <= last) and (index == -1):      
        mid = (first+last)//2
        if mas[mid] == n:
            index = mid
        else:
            if n<mas[mid]:
                last = mid -1
            else:
                first = mid +1
    return index

# %%
#Бинарное дерево
class Node:
    def __init__(self, key):
        self.key = key
        self.left = None
        self.right = None

def inorder(root):
    if root is not None:
        inorder(root.left)
        print(str(root.key),end=' ')
        inorder(root.right)

def insert(node, key):
    if node is None:
        return Node(key)
    if key < node.key:
        node.left = insert(node.left, key)
    else:
        node.right = insert(node.right, key)
    return node

def minValueNode(node):
    current = node
    while(current.left is not None):
        current = current.left
    return current

def deleteNode(root, key):
    if root is None:
        return root
    if key < root.key:
        root.left = deleteNode(root.left, key)
    elif(key > root.key):
        root.right = deleteNode(root.right, key)
    else:   
        if root.left is None:
            temp = root.right
            root = None
            return temp
        elif root.right is None:
            temp = root.left
            root = None
            return temp
        temp = minValueNode(root.right)
        root.key = temp.key
        root.right = deleteNode(root.right, temp.key)
    return root
      
def search(root,n,m):
    if root is not None:
        search(root.left,n,m)
        if root.key==n:
            print(f'Элемент {n} есть в последовательности')
            return
        elif root.key==m:
            print(f'Элемента {n} в последовательности нет')
        search(root.right,n,m)              
    
def add(val,root):
    root = insert(root, val)
    inorder(root)
    
def delite(val,root):
    root = deleteNode(root, val)
    inorder(root)
    
def tree_search(mas,root):
    for i in range(len(mas)):
        root = insert(root, mas[i])
    return root

# %%
#Метод Фибоначчи
def fib_search(mas,n):
    fibM_minus_2 = 0
    fibM_minus_1 = 1
    fibM = fibM_minus_1 + fibM_minus_2
    while (fibM < len(mas)):
        fibM_minus_2 = fibM_minus_1
        fibM_minus_1 = fibM
        fibM = fibM_minus_1 + fibM_minus_2
    index = -1;
    while (fibM > 1):
        i = min(index + fibM_minus_2, (len(mas)-1))
        if (mas[i] < n):
            fibM = fibM_minus_1
            fibM_minus_1 = fibM_minus_2
            fibM_minus_2 = fibM - fibM_minus_1
            index = i
        elif (mas[i] > n):
            fibM = fibM_minus_2
            fibM_minus_1 = fibM_minus_1 - fibM_minus_2
            fibM_minus_2 = fibM - fibM_minus_1
        else :
            return i
    if(fibM_minus_1 and index < (len(mas)-1) and mas[index+1] == n):
        return index+1;
    return -1

# %%
#Интерполяционный
def interpolation_search(mas,n):
    low = 0
    high = (len(mas) - 1)
    while low <= high and n >= mas[low] and n <= mas[high]:
        index = low + int(((float(high - low) / ( mas[high] - mas[low])) * ( n - mas[low])))
        if mas[index] == n:
            return index
        if mas[index] < n:
            low = index + 1;
        else:
            high = index - 1;
    return -1

# %%
def type_search_void(type_serch,n):
    index=0   
    if type_serch==1:      
        index=bin_search(mas,n)   
    elif type_serch==3:
        index=fib_search(mas,n)  
    elif type_serch==4:
        index=interpolation_search(mas,n)
    if index==-1:
        print('данного элемента в последовательности не существует!')
        return -1
    else:
        return index  
    
def type_action_void(mas,index,type_action):
    if type_action==1:      
        print('Элемент находится под индексом:',index)
    elif type_action==2:
        num = int(input('Введите элемент для добавления в массив:'))
        print('_'*120)
        mas.insert(index+1,num)
        print('Массив с добавленным элементом, после числа ',n,':\n',mas,sep='')     
    elif type_action==3:
        mas.pop(index)
        print('Массив с удалённым элементом ',n,':\n',mas,sep='') 
        
def type_action_void_2(type_action,root):
    if type_action==1:  
        n=int(input('Введите искомое число:'))
        search(root,n,max(mas))
    elif type_action==2:
        num = int(input('Введите элемент для добавления в массив:'))
        print('_'*120)
        add(num,root)   
    elif type_action==3:
        num = int(input('Введите элемент для удаления из массива:'))
        print('_'*120)
        delite(num,root)
        
type_serch=int(input('Введите тип поиска:\n1-Бинарный поиск\n2-Бинарное дерево\n3-Метод Фибоначчи\n4-Интерполяционный\n\n'))
print('_'*120,)
type_action=int(input('Что нужно сделать:\n1-Найти элемент\n2-Добавить элемент\n3-Удалить элемент\n\n'))
print('_'*120)
mas=generator(10,0,100)
mas=sorted(mas)
print('Исходная последовательность:\n',mas)
print('_'*120)
if type_serch!=2:
    n=int(input('Введите искомое число:'))
    index=type_search_void(type_serch,n)
    if index!=-1:
        print('_'*120,'\n')
        type_action_void(mas,index,type_action)
elif type_serch==2:
    root = None
    root=tree_search(mas,root)
    print('_'*120,'\n')
    type_action_void_2(type_action,root)
# Out:
# Введите тип поиска:
# 1-Бинарный поиск
# 2-Бинарное дерево
# 3-Метод Фибоначчи
# 4-Интерполяционный
#
# 1
# ________________________________________________________________________________________________________________________
# Что нужно сделать:
# 1-Найти элемент
# 2-Добавить элемент
# 3-Удалить элемент
#
# 1
# ________________________________________________________________________________________________________________________
# Исходная последовательность:
#  [2, 5, 7, 24, 53, 61, 67, 70, 84, 91]
# ________________________________________________________________________________________________________________________
# Введите искомое число:7
# ________________________________________________________________________________________________________________________
#
# Элемент находится под индексом: 2

# %% [markdown]
# ### Задание №2
# Написать соответствующие решения для заданных методов.

# %%
#Простое рехэширование
import random
def gethash(x, n):
    return 100 + x % n


def find(addresses, x, n):
    address = gethash(x, n)
    while addresses[address] != x:
        address += 10
    return address


mas = []
n = 10
for i in range(n):
    mas.append(random.randint(0, 100))
addresses = dict()
for num in mas:
    address = gethash(num, n)
    while addresses.get(address):
        address += 10
    addresses[address] = num
print(mas)
print(addresses)
# Out:
# [50, 31, 53, 56, 54, 33, 86, 6, 86, 41]
# {100: 50, 101: 31, 103: 53, 106: 56, 104: 54, 113: 33, 116: 86, 126: 6, 136: 86, 111: 41}

# %%
#Рехэширование с помощью псевдослучайных чисел
import random
def gethash(x, n, add):
    return x % n + add


def find(addresses, x, n, mas_hash):
    address = gethash(x, n, mas_hash[0])
    i = 1
    while addresses[address] != x:
        address = gethash(x, n, mas_hash[i])
        i += 1
    return address


mas = []
n = 10
for i in range(n):
    mas.append(random.randint(0, 100))
mas_hash = []
m = 15
for i in range(m):
    mas_hash.append(random.randint(10, 20))
addresses = dict()
for num in mas:
    address = gethash(num, n, mas_hash[0])
    i = 1
    while addresses.get(address):
        address = gethash(num, n, mas_hash[i])
        i += 1
    addresses[address] = num
print(mas)
print(mas_hash)
print(addresses)
# Out:
# [82, 41, 14, 2, 5, 86, 69, 94, 94, 37]
# [18, 17, 10, 18, 18, 17, 12, 15, 18, 18, 17, 10, 12, 12, 15]
# {20: 82, 19: 41, 22: 14, 12: 2, 23: 5, 24: 86, 27: 69, 21: 94, 14: 94, 25: 37}

# %%
#Метод цепочек
import random
def gethash(x, n):
    return 100 + x % n


def find(addresses, x, n):
    address = gethash(x, n)
    i = 0
    temp = addresses.get(address)
    while temp[i] != x:
        i += 1
    return address


mas = []
n = 10
for i in range(n):
    mas.append(random.randint(0, 100))
print(mas)
addresses = dict()
for num in mas:
    address = gethash(num, n)
    if addresses.get(address):
        addresses[address].append(num)
    else:
        addresses[address] = [num]
print(addresses)
# Out:
# [8, 83, 35, 26, 75, 95, 26, 61, 70, 64]
# {108: [8], 103: [83], 105: [35, 75, 95], 106: [26, 26], 101: [61], 100: [70], 104: [64]}

# %% [markdown]
# ### Задание №3
# Расставить на стандартной 64-клеточной шахматной доске 8 ферзей так, чтобы ни один из них не находился под боем другого». Подразумевается, что ферзь бьёт все клетки, расположенные по вертикалям, горизонталям и обеим диагоналям
# Написать программу,  которая находит хотя бы один способ решения задач.

# %%
def check_open_point(mas):
    open_list=[]
    for i in range(len(mas)):
        for j in range(len(mas[0])):
            if mas[i][j]==0:
                open_list.append((i,j))
    return open_list
    
    
def print_matrix_ferz(f_list):
    mas=[['☐' for i in range(8)]for i in range(8)]
    for i in range(len(f_list)):
        if f_list[i][0]!=-1:
            mas[f_list[i][0]][f_list[i][1]]='♕'
    for i in range(len(mas)):
        for j in range(len(mas[i])):
            print(mas[i][j], end=' ')
        print()
    print('\n')
    
    
def add_ferz(mas,n,m):
    for i in range(8):
        mas[n][i]=1
        mas[i][m]=1
    for i in range(8):
        if n+i<8 and m+i<8:
            mas[n+i][m+i]=1
        if n+i<8 and m-i>0:
            mas[n+i][m-i]=1
        if n-i>=0 and m-i>=0:
            mas[n-i][m-i]=1
        if n-i>=0 and m+i<8:
            mas[n-i][m+i]=1
    return mas
    

def arrangement_of_queens2():
    count=0
    open_pos=[0 for i in range(10)]
    ferz_list=[(-1,-1) for i in range(8)]
    mas=[[0 for i in range(8)]for i in range(8)]
    while count<7:
        if len(check_open_point(mas))-open_pos[count]>0:
            open_pos[count]+=1
            ferz_list[count]=check_open_point(mas)[open_pos[count]]
            mas=add_ferz(mas,ferz_list[count][0],ferz_list[count][1])
            if len(check_open_point(mas))>0:
                count+=1
            else:
                open_pos[count]+=1
                ferz_list[count]=(-1,-1)
                mas=[[0 for i in range(8)]for i in range(8)]
                count-=1
                for i in range(8):
                    if ferz_list[i][0]!=-1:
                        mas=add_ferz(mas,ferz_list[i][0],ferz_list[i][1])
        else:
            open_pos[count]=0
            count-=1
            open_pos[count]+=1
            ferz_list[count]=(-1,-1)
            mas=[[0 for i in range(8)]for i in range(8)]
            for i in range(8):
                if ferz_list[i][0]!=-1:
                    mas=add_ferz(mas,ferz_list[i][0],ferz_list[i][1])
    open_pos[count]+=1
    ferz_list[count]=check_open_point(mas)[0]
    mas=add_ferz(mas,ferz_list[count][0],ferz_list[count][1])
    count+=1
    return count,ferz_list


count,f_list=arrangement_of_queens2()
print('Количество ферзей =',count,'\n')
print_matrix_ferz(f_list)
# Out:
# Количество ферзей = 8
#
# ☐ ♕ ☐ ☐ ☐ ☐ ☐ ☐
# ☐ ☐ ☐ ♕ ☐ ☐ ☐ ☐
# ☐ ☐ ☐ ☐ ☐ ♕ ☐ ☐
# ☐ ☐ ☐ ☐ ☐ ☐ ☐ ♕
# ☐ ☐ ♕ ☐ ☐ ☐ ☐ ☐
# ♕ ☐ ☐ ☐ ☐ ☐ ☐ ☐
# ☐ ☐ ☐ ☐ ☐ ☐ ♕ ☐
# ☐ ☐ ☐ ☐ ♕ ☐ ☐ ☐
