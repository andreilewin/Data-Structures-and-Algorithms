# %%
# Лабораторная работа №1
## Выполнил студент группы БФИ2001 Левин А.С

# %%
### Задание №1
print("Hello,World")
# Out:
# Hello,World

# %%
### Задание №2

# 1. Подключить модуль random для формирования
# случайных чисел
import random

# 2. Ввести размерность матрицы
m = 50
n = 50

min_limit = -250
max_limit = 1013
Matrix = [ [ random.randint(min_limit, max_limit) for j in range(n)] for i in range(m) ]
print('Matrix:')

# 4. Вывести результат
for i in range(m):
    print(Matrix[i])
# Out:
# Matrix:
# [399, -250, 560, 236, 55, 425, 240, 803, 12, 289, 796, 487, 792, 40, 661, 270, -235, 34, 32, 24, 552, 569, 443, 428, 633, 170, 323, 225, 368, 805, 123, -153, 838, 759, 379, 696, -247, 801, 149, 398, 514, 432, 358, 862, -37, 703, 812, 425, -21, -44]
# [17, -14, 508, 514, 134, 416, 830, 273, 21, 307, -90, 874, 503, 714, 278, 240, 830, 38, -56, -211, 501, 37, 149, -18, 623, 814, 911, 36, -69, 76, 94, 276, 781, 443, 622, 717, -143, 571, 542, 805, -53, 745, 151, 709, 969, 85, 442, 936, 376, 456]
# [-111, -223, 350, -210, 460, 213, -85, -104, -237, 70, 180, 146, -188, 538, 882, -124, -218, 913, 935, 73, 574, 0, -112, -43, -82, 996, 348, 501, 491, 326, 278, 723, 764, -163, 745, -211, 669, -165, -183, 312, -196, -197, -141, 847, 570, 644, 777, 865, 253, 673]
# ...

# %%
import random
n=20
min_limit = -250
max_limit = 1011
list_n=[ random.randint(min_limit, max_limit) for j in range(n)]
print (list_n)
# Out:
# [248, 162, 604, 905, 265, 273, 653, 73, 882, -91, 927, -109, 749, 85, 809, -67, 85, 357, 514, -188]
